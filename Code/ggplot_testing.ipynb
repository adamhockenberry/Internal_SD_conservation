# %%
# %matplotlib inline

# %%
import ggplot
from matplotlib import pyplot as plt

# %%
basic_plot = ggplot.ggplot(ggplot.aes(x='date', y='beef'), data=ggplot.meat) + ggplot.theme_bw() +\
ggplot.theme(axis_text=ggplot.element_text(size=20, color='green'), x_axis_text=ggplot.element_text(angle=45))

# %%
basic_plot + ggplot.geom_point()
# Out:
# <ggplot: (-9223372036574255472)>

# %%
p + geom_point() + geom_line()

# %%
p + geom_point() + geom_line() + stat_smooth(color='blue')

# %%
ggplot.ggplot(ggplot.pigeons, ggplot.aes(x='pos', y='speed')) + \
    ggplot.geom_point() + \
    ggplot.stat_smooth(color='red')

# %%
plt.figure()
plt.hist2d(ggplot.meat['veal'], ggplot.meat['beef'], 20, cmap='gray_r');
plt.plot(ggplot.meat['veal'], ggplot.meat['beef'], color='k', marker='o', linestyle='', alpha=0.1)

# %%
plt.hist()
# Out:
#           date    beef   veal    pork  lamb_and_mutton  broilers  \
# 0   1944-01-01   751.0   85.0  1280.0             89.0       NaN
# 1   1944-02-01   713.0   77.0  1169.0             72.0       NaN
# 2   1944-03-01   741.0   90.0  1128.0             75.0       NaN
# 3   1944-04-01   650.0   89.0   978.0             66.0       NaN
# 4   1944-05-01   681.0  106.0  1029.0             78.0       NaN
# 5   1944-06-01   658.0  125.0   962.0             79.0       NaN
# 6   1944-07-01   662.0  142.0   796.0             82.0       NaN
# 7   1944-08-01   787.0  175.0   748.0             87.0       NaN
# 8   1944-09-01   774.0  182.0   678.0             91.0       NaN
# 9   1944-10-01   834.0  215.0   777.0            100.0       NaN
# 10  1944-11-01   786.0  197.0   944.0             91.0       NaN
# 11  1944-12-01   764.0  146.0  1013.0             91.0       NaN
# 12  1945-01-01   820.0  119.0  1037.0            100.0       NaN
# ...
